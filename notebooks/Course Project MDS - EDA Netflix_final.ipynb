# %% [markdown]
# # Курсовой проект, MDS
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# ## Курсовой проект. Exploratory Data Analysis

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 11.03.2026
#
# __Защита проекта:__ ~ 20.06.2025

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Курсовой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 4 до 6 человек. В то же время, следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняему ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой, в обязательном порядке проверяется и учитывается в оценке вклад ***каждого участника*** в общую работу команды. Вследствие этого, крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости, команда большинством голосов имеет право исключить человека из команды *до защиты проекта*, сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/1AfaFIfCVB21uwLcatl0LpXGxKqDKCJ3jo7F-7Ji4usg/edit?usp=sharing

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(11032026)`.
#
# Для сохранения справедливости и беспристрастности случайного распределения, любые переводы команд между комиссиями (смена комиссии) не допускаются. Присутствие студента на защите проекта является обязательным; вклад студента при его отсутствии не оценивается и автоматически считается равным нулю. Кроме того, во время защиты проекта обязательно, чтобы камера оставалась включённой на протяжении всего времени пребывания в конференции.

# %% [markdown]
# ## Описание задания

# %% [markdown]
# <img src="https://pp.userapi.com/c854528/v854528797/c62ce/FiPEibYUxJc.jpg" width="40%">

# %% [markdown]
# Netflix за последние 10-15 лет обзавелись большим количеством зрителей. С увеличением числа зрителей увеличилось и разнообразие шоу. Соответственно, перед аналитиками из киноиндустрии встала задача исследования данных с рейтингами различных сериалов.
#
# В данном задании вам предстоит провести визуальный анализ датасета **1000 Netflix Shows** (по состоянию на 11.06.2017) и сделать выводы.

# %% [markdown]
# ### Описание признаков

# %% [markdown]
# * `title` - название шоу.
# * `rating` - рейтинг шоу. Например: G, PG, TV-14, TV-MA.
# * `ratingLevel` - описание рейтинговой группы и особенностей шоу.
# * `ratingDescription` - рейтинг шоу, закодированный числом.
# * `release year` - год выпуска шоу.
# * `user rating score` - оценка пользователей.
# * `user rating size` - общий рейтинг пользователей.

# %% [markdown]
# ### Требования к проекту

# %% [markdown]
# В качестве результата выполнения курсового проекта ваша команда должна получить презентацию и защитить ее перед комиссией.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта — вам необходимо принять на себя роль аналитиков: провести работу над признаками, исследовать информацию, содержащуюся в датасете,  выявить тенденции, тренды, факты из данных, а также, конечно, презентовать всё это в понятном виде.
#
# Фактически, можно воспринимать этот проект в следующем ключе: к вам пришел некий бизнес-заказчик — например, это может быть непосредственно представитель Netflix, которые хотят улучшить какие-то процессы; или какая-то компания, которая хочет снять какой-то новый проект и/или продать какой-то свой уже готовый продукт Netflix'у; или это может быть некая компания конкурент Netflix'a, которая заинтересована в общем исследовании рынка; или абсолютно любой другой стейхолдер в рамках данной отрасли — и вот этот заказчик просит вас проанализировать данные и извлечь на основе них какие-то полезные и значимые бизнес-инсайты для него. Разумеется, чем глубже, чем осмысленнее и чем нетривиальнее будут эти выводы, тем больше они вам заплатят :)

# %% [markdown]
# ### Примеры вопросов и тем

# %% [markdown]
# Чтобы вы не начинали работу полностью с чистого листа, мы подобрали для вас некоторое количество опорных вопросов, с которых вы можете начать ваш первичный анализ.
#
# **Внимание:** Эти вопросы лишь *приблизительные* и дают только *начальный вектор* для вашего исследования. Хотя качественно проработанные ответы на них и могут принести вам значительное количество первичных инсайтов и полезной информации — не стоит строить весь ваш проект вокруг только ответов на них. По возможности постарайтесь усовершенствовать и развить темы, затрагивающиеся в данных вопросах, либо вообще найти другие слои, которые в рамках них не рассматриваются (на самом деле, таковых довольно много!)

# %% [markdown]
# Итак, сами вопросы:
#
# - Сколько рейтинговых групп представлено в данных?
# - Как рейтинговые группы отличаются друг от друга?
# - Какие оценки пользователи ставят чаще всего?
# - Какие оценки пользователи ставят в среднем?
# - В какие годы были запущены шоу?
# - Можно ли сделать вывод, что 2017 год успешнее для Netflix, чем 2016?
# - Выберите любое шоу (например, самое понравившееся) и составьте его описательный портрет. На какие вопросы о нем вам было бы интересно ответить, если бы вы были заказчиком? Ответьте на эти вопросы :)
# - Какие существуют признаки, не представленные в данных, но существенно влияющие на имеющиеся признаки?
# - Как формируются оценки?
# - Каким образом собирались сами данные?

# %% [markdown]
# Повторимся еще раз: это лишь *примерные вопросы*, для того чтобы дать вам начальный вектор, в котором вы могли бы двигаться. Вы можете отвечать или не отвечать на них по своему усмотрению, а также действовать таким образом и в том направлении, как полностью посчитаете нужным!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев;
# - Не нужно делать просто текстовые слайды;
# - Стройте свой анализ, исходя из того, что ваша цель представить полезную информацию для бизнеса;
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами;
# - Не обязательно ограничиваться представленным датасетом. У вас есть весь интернет, чтобы найти дополнительную информацию и проверить ваши гипотезы. Дерзайте!

# %% [markdown]
# ### Примерный скелет EDA

# %% [markdown]
# Опять-таки, чтобы вам не приходилось начинать написание кода с чистого листа, мы выстроили некий простейший скелет возможных этапов, которые вы могли бы включить в основу вашего первичного анализа.
#
# Как вы уже, наверное, поняли, мы не настаиваем! :)

# %% [markdown]
# # Бизнес-постановка задачи
#
# **Заказчик.** Команда контент-стратегии Netflix - те, кто отбирает и закупает фильмы и сериалы в каталог.
#
# **Бизнес-вопрос.** На какие характеристики контента опираться при отборе и закупке тайтлов, чтобы при ограниченном бюджете получать максимальный охват аудитории?
#
# **Что считаем успехом.** Рост охвата (прокси - число оценок numVotes на IMDb) при сохранении высокого среднего качества каталога.
#
# **Как мы отвечаем на вопрос.** Через анализ данных проверяем, что сильнее всего связано с охватом и качеством: рейтинг, жанр, длительность, год выхода. Главную ставку проверяем отдельно через функцию эластичности - насколько охват чувствителен к качеству.
#
# Все дальнейшие шаги (очистка, обогащение данными IMDb, разведочный анализ и исследование эластичности) подчинены этому вопросу.

# %% [markdown]
# #### Скачайте данные
# Загрузите данные, выполнив код ниже.

# %%
# %pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: pip3.13 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re


# Чтобы любой мог сразу запустить после клона проекта из гитхаба

project_dir = Path.cwd().parent

raw_data_path = project_dir / "data" / "raw" / "NetflixShows.xlsx"
processed_data_path = project_dir / "data" / "processed" / 'NetflixShows_clean.csv'

data_raw = pd.read_excel(raw_data_path)

data_raw.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
print(f'Размер таблицы: {data_raw.shape}')
# Out:
# Размер таблицы: (1000, 7)

# %%
print(f"Названия колонок: {data_raw.columns.tolist()}")
# Out:
# Названия колонок: ['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year', 'user rating score', 'user rating size']

# %%
# Смотрим на типы колонок и на то,
# сколько непустых значений

data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   rating             1000 non-null   object
#  2   ratingLevel        941 non-null    object
#  3   ratingDescription  1000 non-null   int64
#  4   release year       1000 non-null   int64
#  5   user rating score  605 non-null    float64
#  6   user rating size   1000 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
# Считаем пропуски

data_raw.isna().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64

# %%
# Теперь в процентах на всякий, мб для отчета понадобится

miss_count = data_raw.isna().sum()
miss_share = miss_count / data_raw.shape[0] * 100

print("Доля пропусков в процентах:")
miss_share
# Out:
# Доля пропусков в процентах:
# title                 0.0
# rating                0.0
# ratingLevel           5.9
# ratingDescription     0.0
# release year          0.0
# user rating score    39.5
# user rating size      0.0
# dtype: float64

# %%
# Смотрим базовую статистику по числовым колонкам,
# мб сразу что-то вылезет

data_raw.describe().T
# Out:
#                     count         mean        std     min     25%     50%  \
# ratingDescription  1000.0    67.366000  30.785610    10.0    35.0    60.0
# release year       1000.0  2010.335000   8.877927  1940.0  2007.0  2015.0
# user rating score   605.0    84.094215  12.344371    55.0    75.0    88.0
# user rating size   1000.0    80.783000   0.973066    80.0    80.0    80.0
#
#                       75%     max
# ratingDescription    90.0   124.0
# release year       2016.0  2017.0
# user rating score    95.0    99.0
# user rating size     82.0    82.0

# %%
# user rating size странный, посмотрим значения отдельно его

print("Значения user rating size:")
data_raw['user rating size'].value_counts()
# Out:
# Значения user rating size:
# user rating size
# 80    605
# 82    388
# 81      7
# Name: count, dtype: int64

# %%
# и ratingDescription тоже,
# потому что похоже на какой-то числовой код рейтинга

print("Значения ratingDescription:")
data_raw['ratingDescription'].value_counts().sort_index()
# Out:
# Значения ratingDescription:
# ratingDescription
# 10      68
# 35     190
# 41      38
# 42      44
# 60     170
# 70      59
# 80      15
# 90     234
# 100     19
# 110    148
# 124     15
# Name: count, dtype: int64

# %%
# смотрим, как user rating size связан с оценкой

print("user rating size у строк, где есть user rating score:")
data_raw[data_raw['user rating score'].notna()]['user rating size'].value_counts()
# Out:
# user rating size у строк, где есть user rating score:
# user rating size
# 80    605
# Name: count, dtype: int64

# %%
# и тут

print("user rating size у строк, где user rating score пропущен:")
data_raw[data_raw['user rating score'].isna()]['user rating size'].value_counts()
# Out:
# user rating size у строк, где user rating score пропущен:
# user rating size
# 82    388
# 81      7
# Name: count, dtype: int64

# %%
# Смотрим, является ли ratingDescription просто кодом для рейтинга

data_raw.groupby('rating')['ratingDescription'].value_counts()
# Out:
# rating    ratingDescription
# G         35                   138
# NR        124                   14
# PG        60                   170
# PG-13     80                    15
# R         100                   19
# TV-14     90                   234
# TV-G      35                    52
# TV-MA     110                  148
# TV-PG     70                    59
# TV-Y      10                    68
# TV-Y7     41                    38
# TV-Y7-FV  42                    44
# UR        124                    1
# Name: count, dtype: int64

# %% [markdown]
# После проверки видно, что ratingDescription почти работает как числовой код для rating, поэтому для анализа удобнее оставить обычный rating. user rating size тоже выглядит странно, то есть если user rating score заполнен, то user rating size всегда = 80, а если оценка пропущена, то там стоят 81 или 82, поэтому этот признак больше похож на служебный, решил снести эти колонки

# %%
# Делаю копию данных, чтобы с ней работать дальше
# и сношу ненужные служебные колонки

data_work = data_raw.copy()

data_work = data_work.drop(columns=['ratingDescription', 'user rating size'])

data_work.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  release year  \
# 0  crude and sexual humor, language and some drug...          2004
# 1  strong violence, sexual content and adult lang...          2006
# 2  Parents strongly cautioned. May be unsuitable ...          2016
# 3  Parents strongly cautioned. May be unsuitable ...          2008
# 4  Parental guidance suggested. May not be suitab...          2014
#
#    user rating score
# 0               82.0
# 1                NaN
# 2               98.0
# 3               98.0
# 4               94.0

# %% [markdown]
# #### Удалите из данных дубликаты.
# - Почему они возникли?
# - Много ли их? В каких группах их больше всего?

# %%
# Смотрим, сколько было строк до удаления

print(f"Строки до удаления дублей: {data_work.shape[0]}")
# Out:
# Строки до удаления дублей: 1000

# %%
# Теперь именно полные дубли строк
# значит, если их снесем, то 500 и останется

print(f"Полные дубли строк: {data_work.duplicated().sum()}")
# Out:
# Полные дубли строк: 500

# %%
# Смотрим примеры дублей

full_duplicates = data_work[data_work.duplicated() == True]
full_duplicates.head(10)
# Out:
#                     title rating  \
# 50    Lucky Number Slevin      R
# 52         Grey's Anatomy  TV-14
# 53           Prison Break  TV-14
# 56  How I Met Your Mother  TV-PG
# 57           Supernatural  TV-14
# 58           Breaking Bad  TV-MA
# 61    The Vampire Diaries  TV-14
# 67       The Walking Dead  TV-MA
# 68    Pretty Little Liars  TV-14
# 74           Black Mirror  TV-MA
#
#                                           ratingLevel  release year  \
# 50  strong violence, sexual content and adult lang...          2006
# 52  Parents strongly cautioned. May be unsuitable ...          2016
# 53  Parents strongly cautioned. May be unsuitable ...          2008
# 56  Parental guidance suggested. May not be suitab...          2014
# 57  Parents strongly cautioned. May be unsuitable ...          2016
# 58  For mature audiences.  May not be suitable for...          2013
# 61  Parents strongly cautioned. May be unsuitable ...          2017
# ...

# %%
# Смотрим, какие названия чаще всего появляются

data_work['title'].value_counts().head(15)
# Out:
# title
# 13 Reasons Why             8
# Girlboss                   7
# Prison Break               7
# Pretty Little Liars        6
# Shameless (U.S.)           6
# Grace and Frankie          6
# The Secret Life of Pets    6
# New Girl                   6
# The Vampire Diaries        6
# The Iron Giant             6
# Dinotrux                   6
# Anastasia                  6
# Grey's Anatomy             6
# The Client List            5
# The Office (U.S.)          5
# Name: count, dtype: int64

# %%
# Берем самое частое, плюс видим,
# что 13 Reasons Why прост размножился
# одинаковыми строками

data_work[data_work['title'] == '13 Reasons Why']
# Out:
#               title rating                                        ratingLevel  \
# 41   13 Reasons Why  TV-MA  For mature audiences.  May not be suitable for...
# 141  13 Reasons Why  TV-MA  For mature audiences.  May not be suitable for...
# 189  13 Reasons Why  TV-MA  For mature audiences.  May not be suitable for...
# 241  13 Reasons Why  TV-MA  For mature audiences.  May not be suitable for...
# 295  13 Reasons Why  TV-MA  For mature audiences.  May not be suitable for...
# 347  13 Reasons Why  TV-MA  For mature audiences.  May not be suitable for...
# 396  13 Reasons Why  TV-MA  For mature audiences.  May not be suitable for...
# 497  13 Reasons Why  TV-MA  For mature audiences.  May not be suitable for...
#
#      release year  user rating score
# 41           2017               99.0
# 141          2017               99.0
# 189          2017               99.0
# 241          2017               99.0
# 295          2017               99.0
# 347          2017               99.0
# ...

# %%
# Говорили, что датасет хитрый, поэтому
# держим в голове, что одинаковый tile != одинаковая строка

titles = data_work['title'].value_counts()
repeat_titles = titles[titles > 1].index

bad_titles = []

for title in repeat_titles:
    temp = data_work[data_work['title'] == title]
    if temp.drop_duplicates().shape[0] > 1:
        bad_titles.append(title)

bad_titles
# Out:
# ['Bordertown', 'Star Wars: The Clone Wars', 'Goosebumps', 'Skins']

# %%
# Ручками проверяем, что за названия вылезли

data_work[data_work['title'].isin(bad_titles)].sort_values('title')
# Out:
#                          title rating  \
# 167                 Bordertown  TV-14
# 225                 Bordertown  TV-14
# 449                 Bordertown  TV-MA
# 568                 Goosebumps  TV-Y7
# 632                 Goosebumps     PG
# 671                 Goosebumps  TV-Y7
# 151                      Skins  TV-MA
# 181                      Skins  TV-MA
# 504  Star Wars: The Clone Wars     PG
# 512  Star Wars: The Clone Wars  TV-PG
# 554  Star Wars: The Clone Wars     PG
#
#                                            ratingLevel  release year  \
# 167  Parents strongly cautioned. May be unsuitable ...          2016
# 225  Parents strongly cautioned. May be unsuitable ...          2016
# 449  For mature audiences.  May not be suitable for...          2016
# 568             Suitable for children ages 7 and older          1998
# 632  scary and intense creature action and images, ...          2015
# 671             Suitable for children ages 7 and older          1998
# ...

# %%
# Сносим только полные дубли строк, но
# по title не удаляю, потому что записи могут быть разными
# даже с одинаковыми названиями

data_clean = data_work.drop_duplicates().reset_index(drop=True)
print(f"Размер до удаления дублей: {data_work.shape}")
# Out:
# Размер до удаления дублей: (1000, 5)

# %%
print(f"Размер после удаления дублей: {data_clean.shape}")
# Out:
# Размер после удаления дублей: (500, 5)

# %%
print(f"Полных дублей осталось: {data_clean.duplicated().sum()}")
# Out:
# Полных дублей осталось: 0

# %% [markdown]
# После удаления полностью одинаковых строк осталось 500. Они могли появиться из-за повторной выгрузки или объединения одинаковых записей при сборе датасета, больше всего повторов было у тайтлов, например, 13 Reasons Why был 8 раз, Girlboss и Prison Break по 7 раз. При этом удалять строки только по тайтлу нельзя, тк в данных есть одинаковые названия с разными годами, рейтингами или оценками, например Star Wars: The Clone Wars, Goosebumps, Bordertown и Skins, поэтому я удалял только полные дубли строк.

# %%
# Снова считаем пропуски заново

miss_count_clean = data_clean.isna().sum()
miss_share_clean = miss_count_clean / data_clean.shape[0] * 100

print("Кол-во пропусков после удаления дублей:")
miss_count_clean
# Out:
# Кол-во пропусков после удаления дублей:
# title                  0
# rating                 0
# ratingLevel           33
# release year           0
# user rating score    244
# dtype: int64

# %%
print("Доля пропусков после удаления дублей в процентах:")
miss_share_clean
# Out:
# Доля пропусков после удаления дублей в процентах:
# title                 0.0
# rating                0.0
# ratingLevel           6.6
# release year          0.0
# user rating score    48.8
# dtype: float64

# %%
# Смотрим, где нет ratingLevel, но пока не удаляю,
# потому что строки могут быть норм

data_clean[data_clean['ratingLevel'].isna()].head(10)
# Out:
#                       title rating ratingLevel  release year  \
# 25       Marvel's Iron Fist  TV-MA         NaN          2017
# 31    OperaÌ¤Ìµes Especiais  TV-MA         NaN          2015
# 39                 Girlboss  TV-MA         NaN          2017
# 42              Sand Castle  TV-MA         NaN          2017
# 44             Sandy Wexler  TV-14         NaN          2017
# 45          O Amor no DivÌ£  TV-MA         NaN          2016
# 46  Stronger Than the World     NR         NaN          2016
# 48          Happily Married  TV-14         NaN          2015
# 49                  Pandora  TV-MA         NaN          2016
# 72             Ingobernable  TV-MA         NaN          2017
#
#     user rating score
# 25               98.0
# 31                NaN
# 39               94.0
# 42               89.0
# 44               92.0
# 45                NaN
# 46                NaN
# 48                NaN
# 49                NaN
# 72               96.0

# %%
# Смотрим, где чаще всего нет ratingLevel

data_clean[data_clean['ratingLevel'].isna()]['rating'].value_counts()
# Out:
# rating
# TV-MA    22
# TV-14     5
# NR        3
# TV-PG     2
# G         1
# Name: count, dtype: int64

# %%
# Помним про то, что датасет хитрый, проверяем, можно ли восстановить
# ratingLevel через rating, и выясняем, что у некоторых rating куча разных описаний

data_clean.groupby('rating')['ratingLevel'].value_counts()
# Out:
# rating    ratingLevel
# G         General Audiences. Suitable for all ages.                                                                                        52
# NR        This movie has not been rated.                                                                                                    7
# PG        Parental guidance suggested. May not be suitable for children.                                                                   12
#           mild thematic elements                                                                                                            3
#           action and rude humor                                                                                                             1
#                                                                                                                                            ..
# ...

# %%
# считаем, сколько разных ratingLevel есть внутри кждого rating

for rating in data_clean['rating'].unique():
    temp = data_clean[data_clean['rating'] == rating]['ratingLevel'].dropna()
    
    print(rating, "-", len(temp.unique()))
# Out:
# PG-13 - 12
# R - 14
# TV-14 - 2
# TV-PG - 1
# TV-MA - 1
# TV-Y - 1
# NR - 1
# TV-Y7-FV - 1
# UR - 1
# PG - 63
# TV-G - 1
# G - 1
# TV-Y7 - 1

# %%
# теперь смотрим, где чаще всего нет rating score

print("Где user rating score пропущен:")
data_clean[data_clean['user rating score'].isna() == True]['rating'].value_counts()
# Out:
# Где user rating score пропущен:
# rating
# TV-MA       42
# G           34
# TV-14       29
# TV-Y        28
# PG          28
# TV-G        18
# TV-Y7       17
# TV-Y7-FV    17
# TV-PG       12
# NR           8
# R            7
# PG-13        3
# UR           1
# Name: count, dtype: int64

# %%
print("Где user rating score есть:")
data_clean[data_clean['user rating score'].isna() == False]['rating'].value_counts()
# Out:
# Где user rating score есть:
# rating
# TV-14       77
# PG          48
# TV-MA       40
# TV-PG       21
# G           19
# TV-G        11
# PG-13        9
# TV-Y         8
# TV-Y7-FV     8
# R            7
# TV-Y7        6
# NR           2
# Name: count, dtype: int64

# %% [markdown]
# После удаления дублей пропуски остались только в ratingLevel и user rating score.
#
# ratingLevel не заполняю, потому что у некоторых рейтинговых групп есть много разных текстовых описаний. Например, внутри PG, R, PG-13 встречаются разные варианты описаний, а искажать данные мы не хотим
#
# user rating score тоже не заполняю и не удаляю строки с пропусками, оценки юзеров нет у 244 строк из 500, то есть почти у половины очищенного датасета. Если удалить эти строки, мы потеряем слишком много данных, а если заменить, то создадим искусственные оценки, поэтому пропуски оставлены как NaN, а при дальнейшем анализе оценок нужно учитывать, что оценки есть только у 256 строк.

# %% [markdown]
# ### Финальная проверка очищенной таблицы

# %%
# Финально смотрим итоговую структуру

data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              500 non-null    object
#  1   rating             500 non-null    object
#  2   ratingLevel        467 non-null    object
#  3   release year       500 non-null    int64
#  4   user rating score  256 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 19.7+ KB

# %%
# Теперь стату уже по очищенной таблицу

data_clean.describe().T
# Out:
#                    count         mean        std     min     25%     50%  \
# release year       500.0  2010.976000   7.829305  1940.0  2009.0  2014.0
# user rating score  256.0    81.398438  12.730904    55.0    71.0    83.5
#
#                       75%     max
# release year       2016.0  2017.0
# user rating score    93.0    99.0

# %%
# Ну и дальше смотрим, сколько чего осталось

print(f"Уникальных названий: {data_clean['title'].nunique()}")
# Out:
# Уникальных названий: 496

# %%
print(f"Уникальных рейтинговых групп: {data_clean['rating'].nunique()}")
# Out:
# Уникальных рейтинговых групп: 13

# %%
print(f"Уникальных годов выпуска: {data_clean['release year'].nunique()}")
# Out:
# Уникальных годов выпуска: 35

# %%
# Смотрим распределение по рейтинговым группам

data_clean['rating'].value_counts()
# Out:
# rating
# TV-14       106
# TV-MA        82
# PG           76
# G            53
# TV-Y         36
# TV-PG        33
# TV-G         29
# TV-Y7-FV     25
# TV-Y7        23
# R            14
# PG-13        12
# NR           10
# UR            1
# Name: count, dtype: int64

# %%
# И годы выпуска по порядку

data_clean['release year'].value_counts().sort_index()
# Out:
# release year
# 1940      1
# 1976      1
# 1978      1
# 1982      2
# 1986      1
# 1987      1
# 1989      2
# 1990      2
# 1991      1
# 1992      1
# 1993      5
# 1994      4
# 1995      2
# 1996      1
# 1997      9
# 1998      9
# 1999      5
# 2000      7
# 2001      6
# 2002      5
# 2003     11
# 2004      7
# 2005     10
# 2006     10
# 2007      8
# 2008     11
# 2009     10
# 2010     13
# 2011     15
# 2012     27
# 2013     33
# 2014     35
# 2015     61
# 2016    146
# 2017     37
# Name: count, dtype: int64

# %%
# Самые часты года выпуска

data_clean['release year'].value_counts().head(10)
# Out:
# release year
# 2016    146
# 2015     61
# 2017     37
# 2014     35
# 2013     33
# 2012     27
# 2011     15
# 2010     13
# 2008     11
# 2003     11
# Name: count, dtype: int64

# %%
# Помню, что в выводе видел кракозябры, наверное,
# из-за кривой кодировке, поэтому проверим и их тоже

bad_symbols = ['Ì', 'Ò', 'À', '¤', 'µ', '©']
bad_names = []

for title in data_clean['title'].unique():
    title_text = str(title)

    for symbol in bad_symbols:
        if symbol in title_text:
            bad_names.append(title_text)
            break

bad_names
# Out:
# ['ÌÒ Pai, ÌÒ - Look at This',
#  'OperaÌ¤Ìµes Especiais',
#  'O Amor no DivÌ£',
#  'MerlÌ?',
#  'PokÌ©mon: Indigo League',
#  'PokÌ©mon: XY']

# %%
# И еще на всякий смотрим, что все title действительно строки

for title in data_clean['title'].unique():
    if type(title) != str:
        print(title, type(title))
# Out:
# 0.03 <class 'float'>
# 90210 <class 'int'>

# %%
# А у меня тоже есть птички... Собираю странные title в список
# чтобы посмотреть эти строки целиком

bad_title_values = []

for title in data_clean['title'].unique():
    title_text = str(title)
    for symbol in bad_symbols:
        if symbol in title_text:
            bad_title_values.append(title)
            break
    
    if type(title) != str:
        bad_title_values.append(title)

bad_title_values
# Out:
# ['ÌÒ Pai, ÌÒ - Look at This',
#  'OperaÌ¤Ìµes Especiais',
#  0.03,
#  'O Amor no DivÌ£',
#  90210,
#  'MerlÌ?',
#  'PokÌ©mon: Indigo League',
#  'PokÌ©mon: XY']

# %%
# Теперь смотрим те самые строки

data_clean[data_clean['title'].isin(bad_title_values)]
# Out:
#                          title    rating  \
# 21   ÌÒ Pai, ÌÒ - Look at This     TV-MA
# 31       OperaÌ¤Ìµes Especiais     TV-MA
# 32                        0.03     TV-MA
# 45             O Amor no DivÌ£     TV-MA
# 51                       90210     TV-14
# 113                     MerlÌ?     TV-PG
# 325    PokÌ©mon: Indigo League      TV-Y
# 339               PokÌ©mon: XY  TV-Y7-FV
#
#                                            ratingLevel  release year  \
# 21   For mature audiences.  May not be suitable for...          2007
# 31                                                 NaN          2015
# 32   For mature audiences.  May not be suitable for...          2016
# 45                                                 NaN          2016
# 51   Parents strongly cautioned. May be unsuitable ...          2013
# 113  Parental guidance suggested. May not be suitab...          2015
# 325                             Suitable for all ages.          2000
# ...

# %%
# Далее привожу title к тексту, при этом 90210 пусть остается названием,
# а 0.03 поменяю на 3%, потому что эксель прочел название как процент

data_clean['title'] = data_clean['title'].astype(str)

data_clean.loc[data_clean['title'] == '0.03', 'title'] = '3%'

data_clean[data_clean['title'].isin(['3%', '90210'])]
# Out:
#     title rating                                        ratingLevel  \
# 32     3%  TV-MA  For mature audiences.  May not be suitable for...
# 51  90210  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#     release year  user rating score
# 32          2016                NaN
# 51          2013               62.0

# %%
# Смотрим, остались ли еще какие-нибудь title,
# которые не являются строками

for title in data_clean['title'].unique():
    if type(title) != str:
        print(title, type(title))

# %%
# заменим оставшиеся кривые названия там, где понятно что это вообще

r_dict = {
    'ÌÒ Pai, ÌÒ - Look at This': 'Ó Pai, Ó - Look at This',
    'OperaÌ¤Ìµes Especiais': 'Operações Especiais',
    'O Amor no DivÌ£': 'O Amor no Divã',
    'MerlÌ?': 'Merlí',
    'PokÌ©mon: Indigo League': 'Pokémon: Indigo League',
    'PokÌ©mon: XY': 'Pokémon: XY'
}

data_clean['title'] = data_clean['title'].replace(r_dict)

# %%
print(f"Размер таблицы: {data_clean.shape}")
# Out:
# Размер таблицы: (500, 5)

# %%
print(f"Полных дублей после правки title: {data_clean.duplicated().sum()}")
# Out:
# Полных дублей после правки title: 0

# %%
print(f"Уникальных названий после правки title: {data_clean['title'].nunique()}")
# Out:
# Уникальных названий после правки title: 496

# %%
print(f"Колонки: {data_clean.columns.tolist()}")
# Out:
# Колонки: ['title', 'rating', 'ratingLevel', 'release year', 'user rating score']

# %%
print("Пропуски:")
data_clean.isna().sum()
# Out:
# Пропуски:
# title                  0
# rating                 0
# ratingLevel           33
# release year           0
# user rating score    244
# dtype: int64

# %%
data_clean.sample(10)
# Out:
#                                      title rating  \
# 288              Transformers: Rescue Bots  TV-Y7
# 239                            Drugs, Inc.  TV-14
# 101                         Master of None  TV-MA
# 411  Pocahontas II: Journey to a New World   TV-G
# 258                          The West Wing  TV-14
# 204                              Skin Wars  TV-14
# 20                      Masha and the Bear   TV-Y
# 305                        The Jungle Book     PG
# 17                            Black Mirror  TV-MA
# 395                          Cool Runnings     PG
#
#                                            ratingLevel  release year  \
# 288             Suitable for children ages 7 and older          2016
# 239  Parents strongly cautioned. May be unsuitable ...          2015
# 101  For mature audiences.  May not be suitable for...          2015
# 411                             Suitable for all ages.          1998
# ...

# %%
# Записываем все для следующего этапа

data_clean.to_csv(processed_data_path, index=False)

# %%
# Быстрый чек строчек

check = pd.read_csv(processed_data_path)

print(f"Размер сохраненного файла: {check.shape}")

check.head()
# Out:
# Размер сохраненного файла: (500, 5)
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  release year  \
# 0  crude and sexual humor, language and some drug...          2004
# 1  strong violence, sexual content and adult lang...          2006
# 2  Parents strongly cautioned. May be unsuitable ...          2016
# 3  Parents strongly cautioned. May be unsuitable ...          2008
# 4  Parental guidance suggested. May not be suitab...          2014
#
#    user rating score
# 0               82.0
# 1                NaN
# 2               98.0
# 3               98.0
# 4               94.0

# %% [markdown]
# Итоговая таблица для следующего лежит в NetflixShows_clean.csv. В ней осталось 500 строк и 5 колонок: title, rating, ratingLevel, release year и user rating score. Полных дубли почистил, в тайтл все значения приведены к строковому типу, 0.03 исправил на 3%, потому что Excel прочитал название как процент, также часть явно плохих названий тоже поправил, в которых был не уверен, не стал, после этого проверил размер таблицы, дубли, пропуски и тд
#
# Крч, user rating score заполнен только у 256 строк из 500, а ratingLevel имеет 33 пропуска - эт ключевое.

# %% [markdown]
# #### Сколько рейтинговых групп представлено в данных?

# %%
print(f"Кол рейтинговых групп: {data_clean['rating'].nunique()}")
data_clean['rating'].unique()
# Out:
# Кол рейтинговых групп: 13
# array(['PG-13', 'R', 'TV-14', 'TV-PG', 'TV-MA', 'TV-Y', 'NR', 'TV-Y7-FV',
#        'UR', 'PG', 'TV-G', 'G', 'TV-Y7'], dtype=object)

# %% [markdown]
# #### **Возрастные рейтинги**
#
# В данных представленно 13 возрастных рейтингов групп, с помощью поиска в гугле можно разделить данные на 2 группы:
#
# **1. Группа рейтингов для телевидения:**
#
# * TV-14 - детям до 14 лет просмотр не рекомендуется
# * TV-PG - рекомендуется родительский контроль
# * TV-MA - программа предназначена исключительно для взрослых и может содержать контент, не подходящий для детей младше 17 лет
# * TV-Y - программа предназначена для детей всех возрастов
# * TV-Y7 - программа предназначена для детей в возрасте от 7 лет и старше
# * TV-G - программа предназначена для широкой зрительской аудитории и подходит для всех возрастов
# * TV-Y7-FV - программа ориентирована на детей младшего школьного возраста
#
# **2. Группа рейтингов для фильмов:**
#
# * PG-13 - просмотр нежелателен для детей до 13 лет
# * R - фильм предназначен для взрослой аудитории
# * NR - фильм не проходил официальную оценку и сертификацию
# * UR - фильм не проходил официальную оценку и сертификацию
# * PG - фильм или шоу рекомендуется смотреть в присутствии родителей
# * G - фильм не имеет возрастных ограничений и допущен для просмотра зрителям всех возрастов
#
# Рассмотрим категории сериалов и кино раздельно, возможно там будут неочевидные тренды. Добавим новый признак **'tv'**, где значение '1'- сериал, '0'- фильм/мультфильм
#
# Так же будет целесообразно добавить в датасет еще один новый признак **age** и разделим категории рейтингов по возрастным группам, так сказать по ЦА:
#
# 1. Первая группа 'kid' - фильмы и программы для детей (TV-Y, TV-Y7, TV-G, TV-Y7-FV, G)
# 2. Вторая группа 'teen'- фильмы и программы для подростков (TV-14, TV-PG, PG-13, PG)
# 3. Третья группа 'adult' - фильмы и программы для взрослых (TV-MA, R, NR, UR)
#
# Так как тут присутствуют фильмы/сериалы которые предназначены для просмотра с родителями или в семейном кругу, добавим еще один бинарный признак **'family_friendly'**, где '1' - контент предназначенный для просмотра с семьей, а '0' - контент для взрослых:
#
# * '1' - TV-Y, TV-Y7, TV-G, TV-Y7-FV, G, TV-14, TV-PG, PG-13, PG
# * '0' - TV-MA, R, NR, UR

# %%
data_clean['tv'] = data_clean['rating'].apply(lambda x: 1 if x in ['TV-14', 'TV-PG', 'TV-MA', 'TV-Y','TV-Y7', 'TV-G', 'TV-Y7-FV'] else 0)
data_clean['family_friendly'] = data_clean['rating'].apply(lambda x: 1 if x in ['TV-Y', 'TV-Y7', 'TV-G', 'TV-Y7-FV','G', 'TV-14', 'TV-PG', 'PG-13', 'PG'] else 0)

data_clean['age'] = data_clean['rating'].apply(lambda x: 'kid' if x in ['TV-Y', 'TV-Y7', 'TV-G', 'TV-Y7-FV','G'] 
                                else ('teen' if x in ['TV-14', 'TV-PG', 'PG-13', 'PG']
                                else 'adult' ))

data_clean.head(10)
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                          ratingLevel  release year  \
# 0  crude and sexual humor, language and some drug...          2004
# 1  strong violence, sexual content and adult lang...          2006
# 2  Parents strongly cautioned. May be unsuitable ...          2016
# 3  Parents strongly cautioned. May be unsuitable ...          2008
# 4  Parental guidance suggested. May not be suitab...          2014
# 5  Parents strongly cautioned. May be unsuitable ...          2016
# 6  For mature audiences.  May not be suitable for...          2013
# ...

# %% [markdown]
# #### Какие оценки пользователи ставят чаще?
#
# - Постройте гистограмму оценок.
# - Почему именно такие оценки ставят чаще всего?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

#https://plotly.com/python/plotly-express/ документация плотли

# %%
fig = go.Figure()

fig.add_trace(go.Histogram(x = data_clean['user rating score']))
fig.update_layout(
        title='Распределение оценок от пользователей',
        xaxis_title='Оценка',
        yaxis_title='Количество оценок',
        width = 900)

fig.show()

# %% [markdown]
# По гистограмме (она построенна только на тех данных где есть оценки, то есть только на 256 шоу) можно сказать, что в основном пользователи ставят оценки выше среднего, то есть совсем нет оценок ниже 55/100, что уже показывает, что либо все фильмы/сериалы в этом датасете популярные и радуют зрителей, либо у нас на руках датасет только с более-менее либо с совсем успешными и кассовыми тайтлами. Так же распределение скошено, больше значений в оценках 90-100. Было бы интересно рассмотреть что за шой у нас получают оценки 55-65, чтоб выявить какие типы сериалов/фильмов снимать сейчас не стоит, либо  них не стоит вкладываться.

# %%
bottom_score = data_clean[data_clean['user rating score'] <= 65]

bottom_score.groupby(['tv'])['title'].count()
# Out:
# tv
# 0    15
# 1    25
# Name: title, dtype: int64

# %% [markdown]
# Пока что можно заметить что больше плохих оценок у сериалов с рейтингом для TV, но это еще не показатель, надо посмотреть в долях, может шоу для TV в разы больше

# %%
bottom_score[bottom_score['tv']== 1].shape[0] / data_clean[(data_clean['tv']== 1)& (data_clean['user rating score'].notna())].shape[0]
# Out:
# 0.14619883040935672

# %%
bottom_score[bottom_score['tv']== 0].shape[0] / data_clean[(data_clean['tv']== 0)& (data_clean['user rating score'].notna())].shape[0]
# Out:
# 0.17647058823529413

# %% [markdown]
# Да, тут мы уже видим, что больше "плохих" оценок у рейтинговых групп которые без "TV", разница небольшая, но уже можно сделать предположение, что сериалы в целом меньше получаюь низкие оценки по сравнению с фильмами, теперь интересно рассмотреть если в лучших оценках такая же тенденция, то есть если сериалам чаще ставят высокую оценку, будем считать что 90-100 это высокая оценка

# %%
top_score = data_clean[data_clean['user rating score'] >= 90]

top_score.groupby(['tv'])['title'].count()
# Out:
# tv
# 0    31
# 1    60
# Name: title, dtype: int64

# %%
top_score[top_score['tv']== 1].shape[0] / data_clean[(data_clean['tv']== 1)& (data_clean['user rating score'].notna())].shape[0]
# Out:
# 0.3508771929824561

# %%
top_score[top_score['tv']== 0].shape[0] / data_clean[(data_clean['tv']== 0)& (data_clean['user rating score'].notna())].shape[0]
# Out:
# 0.36470588235294116

# %% [markdown]
# Тут еще меньше разница, но чуть-чуть по лучшим оценкам лидируют фильмы но только на 1%. Так что гипотеза, что сериалам в целом ставят высокие оценки особо не подтвердилась, так как их просто в целом больше в датасетах, но если смотреть по долям, то они практически идиентичны

# %% [markdown]
# #### Выведите основную информацию об оценках пользователей
# - Чему равны среднее, стандартное отклонение, минимум, максимум, медиана?
# - Отличаются ли медиана и среднее?
# - Могут ли данные характеристики значительно отличаться? Почему?

# %%
data_clean['user rating score'].describe()
# Out:
# count    256.000000
# mean      81.398438
# std       12.730904
# min       55.000000
# 25%       71.000000
# 50%       83.500000
# 75%       93.000000
# max       99.000000
# Name: user rating score, dtype: float64

# %% [markdown]
# - медиана по оценкам 83,50
# - среднее по оценкам 81,40
#
# Медиана и среднее различаются, но не значительно, скорее всего есть несколько тайтлоа с более низкой оценкой из-за которой среднее ниже, конечно данные признаки могут отличаться, так как медиана более устойчева к выбросам. Можно построить боксплот и посмотреть есть ли выбросы по IQR

# %%
fig = go.Figure()

fig.add_trace(go.Box(x = data_clean['user rating score']))
fig.update_layout(
        title='Распределение оценок от пользователей',
        xaxis_title='Оценка')
fig.show()

# %% [markdown]
# Как видно по боксплоту, выбросов никаких нет по оценкам, так что ничего подозрительного для дальнейшего анализа нет, так же видим что медиана находится ближе к максимуму чем к минимуму, так что как и говорилось ранее, у нас датасет, где больше высоких оценок (уже видели по распределению)

# %% [markdown]
# #### В какие годы были запущены шоу, представленные в датасете?

# %%
print(f"За сколько лет у нас данные {data_clean['release year'].nunique()}")

data_clean.groupby('release year')['title'].count().reset_index()
# Out:
# За сколько лет у нас данные 35
#     release year  title
# 0           1940      1
# 1           1976      1
# 2           1978      1
# 3           1982      2
# 4           1986      1
# 5           1987      1
# 6           1989      2
# 7           1990      2
# 8           1991      1
# 9           1992      1
# 10          1993      5
# 11          1994      4
# 12          1995      2
# 13          1996      1
# 14          1997      9
# 15          1998      9
# 16          1999      5
# 17          2000      7
# 18          2001      6
# 19          2002      5
# 20          2003     11
# 21          2004      7
# 22          2005     10
# 23          2006     10
# 24          2007      8
# 25          2008     11
# 26          2009     10
# 27          2010     13
# 28          2011     15
# 29          2012     27
# 30          2013     33
# 31          2014     35
# 32          2015     61
# 33          2016    146
# 34          2017     37

# %% [markdown]
#  У нас тайтлы за 35 лет с 1940 по 2017. Больше всего данных за 2016 год, там 146 тайтлов, в многие года вообще по одному/двум шоу
#
#  Такая тенденция оценок так же может означать, что больше людей в целом смотрят только вышедшие сериалы/фильмы так как смотрели более старые ДО появления нетфликса в их жизни, либо просто даже не интерисуются более старыми тайтлами. Так же на главной странице всегда есть раздел по типу 'new releases' чтоб продвигать свои новые тайтлы, может на них больше кликают.

# %% [markdown]
# #### Постройте график, показывающий распределение количества запущенных шоу в зависимости от года.
#
# - Наблюдается ли рост?
# - Есть ли выбросы?
# - Что из себя представляют выбросы?
# - Чем могут быть они вызваны?

# %%
fig = go.Figure()

fig.add_trace(go.Histogram(x = data_clean['release year']))
fig.update_layout(
        title='Распределение количества тайтлов по годам',
        xaxis_title='Год',
        yaxis_title='Количество тайтлов',
        width = 1200)

fig.show()

# %% [markdown]
# Рост определенно есть, в нетфликсе оценивают более свежие тайтлы с где-то 15/16 года, для выбросов рассмотрим боксплот, но уже видно что они потенциально есть

# %%
fig = go.Figure()

fig.add_trace(go.Box(x = data_clean['release year']))
fig.update_layout(
        title='Распределение количества тайтлов по годам',
        xaxis_title='Год')
fig.show()

# %%
data_clean[data_clean['release year'] <= 1998]['title'].count()
# Out:
# np.int64(43)

# %% [markdown]
# Если смотреть по боксплоту, то все тайтлы с 1998 и старше являются выбросами, их получается 43 тайтла, что практически 10% от всего датасета, так что не совсем понятно если можно назвать это выбросами.... Может просто кто-то начал смотреть старые фильмы и решил их оценить :))
#
# Вообще стало интересно посмотреть на название этих "выбросов"

# %%
data_clean[data_clean['release year'] <= 1998]
# Out:
#                                                  title    rating  \
# 168                                       The Waterboy     PG-13
# 170                                             Grease        PG
# 265                     The Nightmare Before Christmas        PG
# 270                     The Smurfs and the Magic Flute         G
# 271                     We're Back! A Dinosaur's Story         G
# 283                  The Super Mario Bros. Super Show!     TV-Y7
# 284                                  Power Rangers Zeo  TV-Y7-FV
# 318                   Ninja Turtles: The Next Mutation  TV-Y7-FV
# 321                                         Goosebumps     TV-Y7
# 344                                 The Little Rascals        PG
# 345                                            Flubber        PG
# 376                                               Antz        PG
# 379                                              Annie        PG
# ...

# %% [markdown]
# #### Сравните среднюю оценку пользователей в 2016 со средней оценкой в 2017.
# - Можно ли сделать вывод, что 2017 год успешнее для Netflix? ("Успешнее" значит, что пользователи в среднем ставили более высокие оценки)
# - Как еще можно оценить "Успешность"?

# %%
print(f"Средняя оценка пользователей за 2016 год - {round(data_clean[data_clean['release year'] == 2016]['user rating score'].mean(), 2)}")
print(f"Средняя оценка пользователей за 2017 год - {round(data_clean[data_clean['release year'] == 2017]['user rating score'].mean(), 2)}")
# Out:
# Средняя оценка пользователей за 2016 год - 84.31
# Средняя оценка пользователей за 2017 год - 88.12

# %%
print(f"Кол оценок пользователей за 2016 год - {data_clean[(data_clean['release year'] == 2016) & (data_clean['user rating score'].notna())]['user rating score'].count()}")
print(f"Кол оценок пользователей за 2017 год - {data_clean[(data_clean['release year'] == 2017) & (data_clean['user rating score'].notna())]['user rating score'].count()}")
# Out:
# Кол оценок пользователей за 2016 год - 86
# Кол оценок пользователей за 2017 год - 16

# %% [markdown]
# Сначала обманчиво выглядело, что оценка средняя улучшилась, но размер выборок различается примерно в 5,375 раза! Прежде чем ответить четко про то, выросло ли или нет, стоит провести доп анализ, потому что это будет слишком преждевременное заявление (может добавить больше данных и сериалов за 2017)

# %% [markdown]
# #### Как нагляднее будет показать распределение пользователей по рейтинговым группам?
#
# Ниже представлены два графика, показывающие распределение шоу по рейтинговым группам. Какой тип графика визуально более интерпретируемый? ([Подсказка](https://sun9-40.userapi.com/c854228/v854228652/c754f/j6z5gMjJy2k.jpg))
# Постройте самостоятельно график, который считаете более интерпретируемым. Сделайте вывод.
#
# Может быть, можно использовать и какие-то другие, еще более продвинутые визуализации?

# %% [markdown]
# ![Charts](https://pp.userapi.com/c852024/v852024281/1a53b1/jSOsBIhxK3U.jpg)

# %% [markdown]
# Конечно с таким кол рейтнговых групп нагляднее будет барчарт/гистограма, сначала построим распределение по изнаальным группам, а потом посмотрим распределение уже по тем признакам которые мы добавили

# %%
fig = go.Figure()

fig.add_trace(go.Histogram(x = data_clean['rating']))
fig.update_layout(
        title='Распределение количества тайтлов по возрастным рейтингам',
        xaxis_title='Возрастной рейтинг',
        yaxis_title='Количество тайтлов',
        xaxis=dict(categoryorder='total descending'),
        width = 1200)

fig.show()

# %% [markdown]
# Во первых по гистограмме видим, что в целом как будто у нас больше тайтлов сериалов (с пометкой TV) чем фильмов, так же больше всего у нас контента для группы TV-14, это в оснвном для подростков старше 14 и взрослых (до этого возраста рекомендуется смотреть программу с родителями), меньше всего данных у нас по тайтлам без рейтинга, NR и UR. Интересно будет посмотреть распределение по новому прищнаку 'age'

# %%
fig = go.Figure()

fig.add_trace(go.Histogram(x = data_clean['age']))
fig.update_layout(
        title='Распределение количества тайтлов по возрастным ЦА',
        xaxis_title='Возрастной ЦА',
        yaxis_title='Количество тайтлов',
        xaxis=dict(categoryorder='total descending'),
        width = 1200)

fig.show()

# %% [markdown]
# Ну да, больше всего у нас контента для подростков/ и для детей постарше (просмотр с родителями), меньше всего у нас именно тайтлов для взрослых (туда так же входят тайтлы без рейтинга возрастного)
#
# Посмотрим какие средние оценки выставлябт контенту разных возрастных категорий

# %%
rating_mean = data_clean.groupby('rating')['user rating score'].mean().reset_index()

rating_mean
# Out:
#       rating  user rating score
# 0          G          74.421053
# 1         NR          77.000000
# 2         PG          84.104167
# 3      PG-13          71.444444
# 4          R          85.285714
# 5      TV-14          82.870130
# 6       TV-G          74.363636
# 7      TV-MA          84.825000
# 8      TV-PG          83.809524
# 9       TV-Y          75.000000
# 10     TV-Y7          76.500000
# 11  TV-Y7-FV          72.750000
# 12        UR                NaN

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x = rating_mean['rating'], y= rating_mean['user rating score']))
fig.update_layout(
        title='Средние оценки по возрастным рейтингам',
        xaxis_title='Возрастной рейтинг',
        yaxis_title='Средняя оценка',
        xaxis=dict(categoryorder='total descending'),
        width = 1200)

fig.show()

# %% [markdown]
# Интересно что лидер тут R, но так же таких тайтлов всего 14 в датасете, а с рейтингом может и еще меньше, но вот уже TV-MA уже и в лидирующих позициях и по оценкам и количеству контента, можно предположить, что хотя взрослых тайтлов не так много (если смотреть разбивку по 'age'), но зато таким тайтлам чаще ставят хорошие оценки именно сериальным тайтлам. Что самое главное это то, то сериалам ставят более высокие оценки чем фильмам (в среднем) как мы уже выявили ранеее, и так же выглядит как самый популярный контент это сериалы для взрослых и так же сериалы для возраста +14 (TV-14)

# %% [markdown]
# #### Теперь вам нужно выбрать любое из представленных шоу и при помощи изученных инструментов составить описательный портрет этого шоу :)
#
# Аналитики и Data Scientist-ы очень любят все сравнивать, поэтому при составлении описательного портрета рекомендуем вам сравнить выбранное шоу с другими по каким-либо характеристикам.

# %%
#мой любимый сериал :))

data_clean[data_clean.title == "Grey's Anatomy"]
# Out:
#             title rating                                        ratingLevel  \
# 2  Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#    release year  user rating score  tv  family_friendly   age
# 2          2016               98.0   1                1  teen

# %% [markdown]
# Рассмотрим сериалы за 2016 год, какая там средняя оценка, как "Анатомия Старсти" отличается от других сериалов этого года, по более ранему анализу мы уже знаем, что самая высокая оценка за весь датасет это 99, но мы не знаем за какой это год и за фильм или сериал это

# %%
tv_16 = data_clean[(data_clean['release year'] == 2016) & (data_clean.tv == 1)]
tv_16.head()
# Out:
#                   title rating  \
# 2        Grey's Anatomy  TV-14
# 5          Supernatural  TV-14
# 9   Pretty Little Liars  TV-14
# 10     Once Upon a Time  TV-PG
# 11             Sherlock  TV-14
#
#                                           ratingLevel  release year  \
# 2   Parents strongly cautioned. May be unsuitable ...          2016
# 5   Parents strongly cautioned. May be unsuitable ...          2016
# 9   Parents strongly cautioned. May be unsuitable ...          2016
# 10  Parental guidance suggested. May not be suitab...          2016
# 11  Parents strongly cautioned. May be unsuitable ...          2016
#
#     user rating score  tv  family_friendly   age
# 2                98.0   1                1  teen
# 5                95.0   1                1  teen
# 9                96.0   1                1  teen
# 10               98.0   1                1  teen
# 11               95.0   1                1  teen

# %%
tv_16[tv_16['age']=='teen']['user rating score'].describe()
# Out:
# count    41.000000
# mean     84.463415
# std      12.552087
# min      58.000000
# 25%      74.000000
# 50%      89.000000
# 75%      95.000000
# max      98.000000
# Name: user rating score, dtype: float64

# %%
tv_16['user rating score'].describe()
# Out:
# count    68.000000
# mean     82.808824
# std      12.976738
# min      56.000000
# 25%      74.000000
# 50%      85.500000
# 75%      94.250000
# max      98.000000
# Name: user rating score, dtype: float64

# %% [markdown]
# За этот год выходили довольено сильные сериалы, средняя оценка составила 82,8, но максимальная оценка составляет 98 и наш выбранный сериал входит в топ оценку сериалов нетфликса за 2016 год! Видимо в 2016 мы все смотрели в основном отличные сериалы :))
#
# А если рассматривать сериалы для подростков, то там уже средняя ойенка повыше, целых 84,46 но наш сериал все еще входит в топ по данной категории!

# %% [markdown]
# ### Обогащение данных

# %% [markdown]
# Добавим больше информации об имеющихся фильмах и сериалах.<br>
# Источник - открытые данные IMDb<br>
# <a href='https://datasets.imdbws.com/'>Датасеты</a> **~** <a href='https://developer.imdb.com/non-commercial-datasets/'>Описание признаков</a>

# %%
# загрузка первого датасета
# в нем немного новой информации, возможно используем длительность и жанры
imdb = pd.read_csv(project_dir / 'data' / 'raw' / 'title.basics.tsv.gz', sep='\t', na_values=[r'\N',r'\\N'], low_memory=False)
imdb.shape
# Out:
# (12592453, 9)

# %%
# просмотр
imdb.head(2)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
#
#    isAdult  startYear  endYear runtimeMinutes             genres
# 0        0     1894.0      NaN              1  Documentary,Short
# 1        0     1892.0      NaN              5    Animation,Short

# %%
imdb.duplicated().sum()
# Out:
# np.int64(0)

# %%
imdb.isna().sum()
# Out:
# tconst                   0
# titleType                0
# primaryTitle            24
# originalTitle           24
# isAdult                  0
# startYear          1471451
# endYear           12434125
# runtimeMinutes     8070922
# genres              538672
# dtype: int64

# %%
imdb['titleType'].value_counts()
# Out:
# titleType
# tvEpisode       9729137
# short           1139783
# movie            750061
# video            327355
# tvSeries         301103
# tvMovie          155202
# tvMiniSeries      71084
# tvSpecial         58323
# videoGame         49395
# tvShort           11009
# tvPilot               1
# Name: count, dtype: int64

# %% [markdown]
# Почти везде отсутствует год окончания, большое количество наименований не имеют значений признака длительности, однако, посмотрев на типы контента можно заметить, что большинство строк - это отдельные эпизоды сериалов. Это может объяснить отсутствие информации. Лучше оставим только те категории, с которыми будем дальше работать, заодно сузим датасет только для нужный наименований- это фильмы и сериалы 1940-2017 гг.

# %% [markdown]
# Кино и сериалы будем анализировать отдельно, так как у них могут отличасться признаки, факторы успеха, аудитория и т.д.

# %%
# до разделения заполним пропуски
# год выпуска = 0, т.к. информации нет, но null может помешать
imdb['startYear'] = imdb['startYear'].fillna(0).astype(int)

# для отсутствующих жанров установим "неизвестно"
imdb['genres'] = imdb['genres'].fillna('unknown')

# уберем строки с отсутствующими названиями, колонку с названием на ориг. языке - не будем использовать
imdb = imdb[imdb['primaryTitle'].notna()].drop(columns='originalTitle').reset_index(drop=True)

# %%
# фильтруем данные и сразу разделяем кино и сериалы
imdb_movies = imdb[(imdb['titleType'].isin(['movie','tvMovie'])) & (imdb['startYear']>=1940) & (imdb['startYear']<=2017)]
imdb_shows = imdb[(imdb['titleType'].isin(['tvMiniSeries','tvSeries'])) & (imdb['startYear']>=1940) & (imdb['startYear']<=2017)]

# %%
imdb_movies.isna().mean()
# Out:
# tconst            0.000000
# titleType         0.000000
# primaryTitle      0.000000
# isAdult           0.000000
# startYear         0.000000
# endYear           1.000000
# runtimeMinutes    0.244946
# genres            0.000000
# dtype: float64

# %% [markdown]
# Отсутствие года окончания для фильмов - логично, признак можно полностью удалить. 24% пропусков в признаке длительности пока нас не очень интересуют, возможно именно для наших фильмов данные есть, проверим это после объединения данных.

# %%
imdb_movies = imdb_movies.drop(columns='endYear')

# %%
imdb_shows.isna().mean()
# Out:
# tconst            0.000000
# titleType         0.000000
# primaryTitle      0.000000
# isAdult           0.000000
# startYear         0.000000
# endYear           0.514846
# runtimeMinutes    0.552857
# genres            0.000000
# dtype: float64

# %% [markdown]
# Также большое количество пропусков в годе окончания и длительности, решение об удалении будем принимать после объединения данных.

# %%
# из начальных данных оставляем только фильмы, фильтруя по созданному нами признаку
movies = data_clean[data_clean['tv']==0]
movies.shape[0]
# Out:
# 166

# %%
# функция для нормализации названий - превращает все в lowercase, убирает символы, оставляет только один пробел
def normalize(x):
    x = str(x)
    x = x.lower()
    x = x.replace('&',' and ')
    x = x.replace('–','-')
    x = x.replace('—','-')
    x = re.sub(r'[^a-z0-9\s]', ' ', x)
    x = re.sub(r'\s+', ' ', x)

    return x.strip()

# копии чтобы все работало корректно
movies = movies.copy()
imdb_movies = imdb_movies.copy()

# примение нормализации названий
movies['norm_title'] = movies['title'].apply(normalize)
imdb_movies['norm_title'] = imdb_movies['primaryTitle'].apply(normalize)

# объединение данных только по совпадающим названиям
movies_enriched = pd.merge(movies, imdb_movies, how='inner', on= 'norm_title')

# %%
# фильтрация по году выпуска фильма, так как встерчаются разные фильмы с одинаковыми названиями
movies_enriched = movies_enriched[(movies_enriched['startYear'] == movies_enriched['release year'])]

# если было несколько совпадений - убираем дубликаты по названию и году выпуска
movies_enriched = movies_enriched.drop_duplicates(subset=['title', 'release year'], keep='first').reset_index(drop=True)

print(f"Строк: {movies_enriched.shape[0]}")
print(f"Уникальных фильмов: {movies_enriched['title'].nunique()}")
print(f"Уменьшилось фильмов на {len(movies) - len(movies_enriched)}")
# Out:
# Строк: 121
# Уникальных фильмов: 121
# Уменьшилось фильмов на 45

# %%
movies_enriched.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2             The Hunter      R
# 3             Hyena Road      R
# 4  Sex, Love and Therapy     NR
#
#                                          ratingLevel  release year  \
# 0  crude and sexual humor, language and some drug...          2004
# 1  strong violence, sexual content and adult lang...          2006
# 2                        language and brief violence          2011
# 3  bloody war violence, language throughout and s...          2015
# 4                     This movie has not been rated.          2014
#
#    user rating score  tv  family_friendly    age            norm_title  \
# 0               82.0   0                1   teen          white chicks
# 1                NaN   0                0  adult   lucky number slevin
# 2                NaN   0                0  adult            the hunter
# 3                NaN   0                0  adult            hyena road
# ...

# %%
movies_enriched.isna().mean()
# Out:
# title                0.000000
# rating               0.000000
# ratingLevel          0.016529
# release year         0.000000
# user rating score    0.388430
# tv                   0.000000
# family_friendly      0.000000
# age                  0.000000
# norm_title           0.000000
# tconst               0.000000
# titleType            0.000000
# primaryTitle         0.000000
# isAdult              0.000000
# startYear            0.000000
# runtimeMinutes       0.000000
# genres               0.000000
# dtype: float64

# %% [markdown]
# Нашлись данные о длительности для всех наших фильмов. Отлично! Теперь проделаем аналогичные действия для сериалов.

# %%
# наши сериалы
tv = data_clean[data_clean['tv']==1]
tv.shape
# Out:
# (334, 8)

# %%
# нормализация названий и объединение данных
tv = tv.copy()
imdb_shows = imdb_shows.copy()

tv['norm_title'] = tv['title'].apply(normalize)
imdb_shows['norm_title'] = imdb_shows['primaryTitle'].apply(normalize)

tv_enriched = pd.merge(tv, imdb_shows, how='inner', on= 'norm_title')

# %%
# учитываем то, что в наших данных не всегда точно указывается год выпуска сериалов, иногда это год выпуска того сезона, который добавлен на нетфликс
# берем окошко в 15 лет - чтобы не объединенять оргиналы с ремейками, при этом включить старые и длинные сериалы
tv_enriched = tv_enriched[(tv_enriched['startYear'] <= tv_enriched['release year']) & (tv_enriched['startYear'] >= tv_enriched['release year'] - 15)]

# убираем дубли и случаи неправильных объединений для ремейков и прочих сериалов с одинаковыми названиями
# вычисляем разницу года выпуска нетфликса и imdb
tv_enriched['year_diff'] = tv_enriched['release year'] - tv_enriched['startYear']

# датасет сортируется по возрастанию разницы годов выпуска, удаляется все, кроме самой меньшей разницы - ближайший метч
tv_enriched = (tv_enriched.sort_values('year_diff').drop_duplicates(subset=['title', 'release year'], keep='first'))
tv_enriched = tv_enriched.drop(columns='year_diff').reset_index(drop=True)

print(f"Строк: {tv_enriched.shape[0]}")
print(f"Уникальных шоу: {tv_enriched['title'].nunique()}")
print(f"Уменьшилось сериалов на {len(tv) - len(tv_enriched)}")
# Out:
# Строк: 243
# Уникальных шоу: 242
# Уменьшилось сериалов на 91

# %%
# остался один дубль, уберем вручную
tv_enriched['title'].value_counts().head(3)
# Out:
# title
# Skins                 2
# Revenge               1
# Transformers Prime    1
# Name: count, dtype: int64

# %%
tv_enriched[tv_enriched['title']=='Skins']
# Out:
#      title rating                                        ratingLevel  \
# 146  Skins  TV-MA  For mature audiences.  May not be suitable for...
# 223  Skins  TV-MA                                                NaN
#
#      release year  user rating score  tv  family_friendly    age norm_title  \
# 146          2013                NaN   1                0  adult      skins
# 223          2017                NaN   1                0  adult      skins
#
#         tconst titleType primaryTitle  isAdult  startYear  endYear  \
# 146  tt1755893  tvSeries        Skins        0       2011   2011.0
# 223  tt1755893  tvSeries        Skins        0       2011   2011.0
#
#     runtimeMinutes        genres
# 146             42  Comedy,Drama
# 223             42  Comedy,Drama

# %%
# Skins 2017 - это тв-фильм, в этом датасете его быть не должно, информация о нем некорректна
tv_enriched = tv_enriched[~((tv_enriched['title']=='Skins') & (tv_enriched['ratingLevel'].isna()))]

print(f"Строк: {tv_enriched.shape[0]}")
print(f"Уникальных шоу: {tv_enriched['title'].nunique()}")
# Out:
# Строк: 242
# Уникальных шоу: 242

# %%
tv_enriched.head()
# Out:
#                                       title rating  \
# 0                                   Revenge  TV-PG
# 1                                  Rosewood  TV-14
# 2  Cooper Barrett's Guide to Surviving Life  TV-14
# 3               Abstract: The Art of Design  TV-14
# 4                            Master of None  TV-MA
#
#                                          ratingLevel  release year  \
# 0  Parental guidance suggested. May not be suitab...          2015
# 1  Parents strongly cautioned. May be unsuitable ...          2015
# 2  Parents strongly cautioned. May be unsuitable ...          2016
# 3                                                NaN          2017
# 4  For mature audiences.  May not be suitable for...          2015
#
#    user rating score  tv  family_friendly    age  \
# 0               84.0   1                1   teen
# 1               81.0   1                1   teen
# 2                NaN   1                1   teen
# 3                NaN   1                1   teen
# ...

# %%
tv_enriched.isna().mean()
# Out:
# title                0.000000
# rating               0.000000
# ratingLevel          0.033058
# release year         0.000000
# user rating score    0.417355
# tv                   0.000000
# family_friendly      0.000000
# age                  0.000000
# norm_title           0.000000
# tconst               0.000000
# titleType            0.000000
# primaryTitle         0.000000
# isAdult              0.000000
# startYear            0.000000
# endYear              0.111570
# runtimeMinutes       0.074380
# genres               0.000000
# dtype: float64

# %% [markdown]
# Для большинства наименований есть данные о endYear и runtimeMinutes, такое количество пропусков не должно сильно повлиять на наш анализ. Слабое место в обоих датасетах сейчас - user rating score ~40% пропусков для фильмов и сериалов. Следует найти и дополнить эту информацию.

# %% [markdown]
# Продолжим работать с IMDb  и рассмотрим возможность использования рейтинга IMDb в качестве основной оценки зрителей, вместо user rating score.

# %%
# загрузка новых данных - рейтинги
imdb_ratings = pd.read_csv(project_dir / 'data' / 'raw' / 'title.ratings.tsv.gz', sep='\t', na_values=[r'\N',r'\\N'])
imdb_ratings.shape
# Out:
# (1684240, 3)

# %%
# просмотр
imdb_ratings.head(2)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2213
# 1  tt0000002            5.4       319

# %%
print('Пропусков:', imdb_ratings.isna().sum().sum())
print('Дубликатов:', imdb_ratings.duplicated().sum())
# Out:
# Пропусков: 0
# Дубликатов: 0

# %% [markdown]
# Данные изначально готовы к использованию - идеально. Объеденим с нашими датасетами.

# %%
# здесь для объединения используется айди фильма/сериала по IMDb
movies_enriched = pd.merge(movies_enriched, imdb_ratings, on='tconst', how='left')
tv_enriched = pd.merge(tv_enriched, imdb_ratings, on='tconst', how='left')

# %%
movies_enriched[['averageRating','numVotes']].isna().mean()
# Out:
# averageRating    0.0
# numVotes         0.0
# dtype: float64

# %%
tv_enriched[['averageRating','numVotes']].isna().mean()
# Out:
# averageRating    0.028926
# numVotes         0.028926
# dtype: float64

# %% [markdown]
# Для всех фильмов и большинства сериалов найден рейтинг и количество голосов - это значительно полезнее, чем user rating score с большим количеством отсутствующих значений. user rating score на данном этапе можно опустить, в качестве оценки рейтинга сериала далее использовать рейтинг IMDb (averageRating)

# %%
# убираем лишние колонки
tv_enriched = tv_enriched.drop(columns=['user rating score','ratingLevel','tv','norm_title','tconst','primaryTitle'])
movies_enriched = movies_enriched.drop(columns=['user rating score','ratingLevel','tv','norm_title','tconst','primaryTitle'])

# %%
# еще пару моментов
print(movies_enriched['isAdult'].value_counts())
print(tv_enriched['isAdult'].value_counts())
# Out:
# isAdult
# 0    121
# Name: count, dtype: int64
# isAdult
# 0    242
# Name: count, dtype: int64

# %%
tv_enriched['endYear'] = tv_enriched['endYear'].fillna(0).astype(int)
tv_enriched = tv_enriched.drop(columns='isAdult')
tv_enriched = tv_enriched.rename(columns={'averageRating':'IMDb Rating',
                                          'release year': 'netflix_year',})

tv_enriched.head()
# Out:
#                                       title rating  netflix_year  \
# 0                                   Revenge  TV-PG          2015
# 1                                  Rosewood  TV-14          2015
# 2  Cooper Barrett's Guide to Surviving Life  TV-14          2016
# 3               Abstract: The Art of Design  TV-14          2017
# 4                            Master of None  TV-MA          2015
#
#    family_friendly    age     titleType  startYear  endYear runtimeMinutes  \
# 0                1   teen  tvMiniSeries       2015     2015            NaN
# 1                1   teen      tvSeries       2015     2017             42
# 2                1   teen      tvSeries       2016     2016            NaN
# 3                1   teen      tvSeries       2017     2019             45
# 4                0  adult      tvSeries       2015     2021             30
#
#                 genres  IMDb Rating  numVotes
# 0               Action          NaN       NaN
# ...

# %%
movies_enriched = movies_enriched.drop(columns='isAdult')
movies_enriched = movies_enriched.rename(columns={'averageRating':'IMDb Rating'})

movies_enriched.head()
# Out:
#                    title rating  release year  family_friendly    age  \
# 0           White Chicks  PG-13          2004                1   teen
# 1    Lucky Number Slevin      R          2006                0  adult
# 2             The Hunter      R          2011                0  adult
# 3             Hyena Road      R          2015                0  adult
# 4  Sex, Love and Therapy     NR          2014                0  adult
#
#   titleType  startYear runtimeMinutes                    genres  IMDb Rating  \
# 0     movie       2004            109              Comedy,Crime          5.9
# 1     movie       2006            110      Crime,Drama,Thriller          7.7
# 2     movie       2011            100  Adventure,Drama,Thriller          6.7
# 3     movie       2015            120                 Drama,War          6.5
# 4     movie       2014             88            Comedy,Romance          5.4
#
#    numVotes
# 0    195370
# 1    339427
# 2     42774
# 3     10053
# 4      2514

# %%
movies_enriched.to_csv(project_dir / 'data' / 'processed' / 'movies_enriched.csv', index=False)
tv_enriched.to_csv(project_dir / 'data' / 'processed' / 'tv_enriched.csv', index=False)

# %% [markdown]
# # Часть 2. Углубленный анализ обогащенных данных
#
# выше очистили данные и обогатили их через IMDb (длительность, жанры, рейтинг IMDb, число оценок). Дальше мы разбираем:
# - жанры
# - длительность
# - динамику по годам
# - сравнение рейтинга IMDb с пользовательской оценкой
#
# важный кооммент: данные подгружаются заново из запроцешенных файлов, чтобы раздел можно было запускать независимо от прошлых чаастей

# %%
# подгружаем готовые данные заново, чтобы раздел работал сам по себе
import pandas as pd
import numpy as np
from pathlib import Path

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default="plotly_mimetype+notebook"

import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

project_dir = Path.cwd().parent

movies = pd.read_csv(project_dir / 'data' / 'processed' / 'movies_enriched.csv')
tv = pd.read_csv(project_dir / 'data' / 'processed' / 'tv_enriched.csv')
clean = pd.read_csv(project_dir / 'data' / 'processed' / 'NetflixShows_clean.csv')

#приводим год выпуска  к единому стандартику
movies = movies.rename(columns={'release year':'year'})
tv = tv.rename(columns={'netflix_year':'year'})

print('кино:',movies.shape,'\nсериалы:',tv.shape)
movies.head()
# Out:
# кино: (121, 11)
# сериалы: (242, 12)
#                    title rating  year  family_friendly    age titleType  \
# 0           White Chicks  PG-13  2004                1   teen     movie
# 1    Lucky Number Slevin      R  2006                0  adult     movie
# 2             The Hunter      R  2011                0  adult     movie
# 3             Hyena Road      R  2015                0  adult     movie
# 4  Sex, Love and Therapy     NR  2014                0  adult     movie
#
#    startYear  runtimeMinutes                    genres  IMDb Rating  numVotes
# 0       2004             109              Comedy,Crime          5.9    195370
# 1       2006             110      Crime,Drama,Thriller          7.7    339427
# 2       2011             100  Adventure,Drama,Thriller          6.7     42774
# 3       2015             120                 Drama,War          6.5     10053
# 4       2014              88            Comedy,Romance          5.4      2514

# %%
# простые новые признаки для обоих наборов
for df in [movies,tv]:
    df['decade'] =(df['year'] // 10*10).astype(int)         
    df['n_genres'] = df['genres'].fillna('unknown').str.split(',').apply(len)
    df['primary_genre'] =df['genres'].fillna('unknown').str.split(',').str[0]
    df['log_votes']=np.log10(df['numVotes'].replace(0,np.nan))

#псколько лет шоу было в эфире
tv['years_on_air'] =tv['endYear'].replace(0,np.nan) - tv['startYear'] +1

movies[['title','year','decade','primary_genre','n_genres','log_votes']].head()
# Out:
#                    title  year  decade primary_genre  n_genres  log_votes
# 0           White Chicks  2004    2000        Comedy         2   5.290858
# 1    Lucky Number Slevin  2006    2000         Crime         3   5.530746
# 2             The Hunter  2011    2010     Adventure         3   4.631180
# 3             Hyena Road  2015    2010         Drama         2   4.002296
# 4  Sex, Love and Therapy  2014    2010        Comedy         2   3.400365

# %% [markdown]
# ## 2.1 Жанры
#
#
# В исходном датасете жанров не было - они появились только после обогащения датасетами IMDb, один тайтл может относиться сразу к нескольким жанрам поэтому раскладываем список жанров по строкам и считаем частоты отдельно для кино и сериалов

# %%
# раскладываем жанры по строкам и берем топ-10
def genre_counts(df,kindd):
    g = df.assign(genre=df['genres'].fillna('unknown').str.split(',')).explode('genre')
    out =g['genre'].value_counts().head(10).reset_index()
    out.columns =['genre', 'count']
    out['kind'] =kindd
    
    return out

gc = pd.concat([genre_counts(movies, 'Кино'), genre_counts(tv, 'Сериалы')])

fig = px.bar(gc, x='count', y='genre', color='kind', barmode='group', orientation='h',
             title='Топ-10 жанров: кино и сериалы',
             labels={'count':'колво тайтлов','genre':'жанры','kind':''})
fig.update_layout(yaxis={'categoryorder': 'total ascending'})
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="e7469382-4906-48c9-b769-ababbbbf1cff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e7469382-4906-48c9-b769-ababbbbf1cff")) {                    Plotly.newPlot(                        "e7469382-4906-48c9-b769-ababbbbf1cff",                        [{"alignmentgroup":"True","hovertemplate":"=Кино\u003cbr\u003eколво тайтлов=%{x}\u003cbr\u003eжанры=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Кино","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Кино","offsetgroup":"Кино","orientation":"h","showlegend":true,"textp
# ...

# %%
# средний рейтинг imdb по жанрам у сериалов ,берем жанры, где хотя бы 10 таитлрв
g  =tv.assign(genre=tv['genres'].fillna('unknown').str.split(',')).explode('genre')
gr=g.groupby('genre').agg(n=('genre','size'),rating=('IMDb Rating','mean')).reset_index()
gr=gr[gr['n'] >= 10].sort_values('rating')

fig = px.bar(gr, x='rating', y='genre', orientation='h', color='rating',
             color_continuous_scale='RdYlGn',
             title='Средний рейтинг IMDb по жанрам ',
             labels={'rating':'средний рейтинг IMDb','genre':'жанр'})


fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="d2fd4be6-1818-4376-9592-84b9b35f9fbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d2fd4be6-1818-4376-9592-84b9b35f9fbd")) {                    Plotly.newPlot(                        "d2fd4be6-1818-4376-9592-84b9b35f9fbd",                        [{"hovertemplate":"средний рейтинг IMDb=%{marker.color}\u003cbr\u003eжанр=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"OqiDOqiDGUBJkiRJkiQbQB5\u002fOODxhxtAV8JvJfxWHEALWchCFrIcQH0\u002fNV66SR5AMzMzMzOzHkC1gU4b6LQeQCu+4iu+4h5AoQ7qoA7qHkA\
# ...

# %% [markdown]
# Видно, что выше всего оценивают сериалы в жанрах Криминал, мистика, драма, триллер - это нишевые, но сильные по рейтингу направления
# А массовые жанры (animation, Family,  comedy) в среднем оцениваются ниже
#
# Для бизнеса это уже инсайт - высокий рейтинг легче получить в драме/триллере, но это не означате нам по дефолту большой охват - его поглядим дальше

# %%
# вложенная структура -- возрастная аудитория ->Ю основной жанр
# размер сектора - эт число тайтлов, цвет -- средний рейтинг IMDb
sb = tv.groupby(['age','primary_genre']).agg(n=('title','size'),rating=('IMDb Rating','mean')).reset_index()
sb = sb[sb['n']>=3]

fig = px.sunburst(
    sb, path=['age','primary_genre'], 
    values='n',color='rating',
        color_continuous_scale='RdYlGn',
    title='Сериалы: аудитория и основной жанр'
)
fig.update_layout(width=800,height=600)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="3ff67c65-23f9-4aa6-8904-a5011ea797f6" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3ff67c65-23f9-4aa6-8904-a5011ea797f6")) {                    Plotly.newPlot(                        "3ff67c65-23f9-4aa6-8904-a5011ea797f6",                        [{"branchvalues":"total","customdata":{"dtype":"f8","bdata":"ZmZmZmZmIED43BKnfs8dQEuf9Emf9B9AagOdNtBpH0DGV3zFV\u002fwaQKIO6qAO6hpALfnFkl8sGUAzMzMzMzMXQM3MzMzMzBxAgoGBgYGBH0B4d3d3d3cbQGxCUPa+Jh5ABVuwBVuwHkAL+7iwjwsfQItDxl67\u002fB5AZ2ZmZmZmGkAjruMm\u002fqYeQA==","shape":"17, 1"},"domain":{"x":[0
# ...

# %% [markdown]
# ## 2.2длительность контента
#
# У кино длительность - это хронометраж фильма, у сериалов в данных IMDb это, как правило, длина одного эпизода
# сравнивать их надо аккуратно

# %%
rt=pd.concat([movies[['runtimeMinutes']].assign(kind='кино'), tv[['runtimeMinutes']].assign(kind='серриалы')]).dropna()
fig=px.box(rt,x='kind',y='runtimeMinutes',color='kind',points='outliers',title='боксплоыты длительности', labels={'runtimeMinutes':'минуты'})
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="73236a50-338a-411f-80e4-d73fc9061b69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("73236a50-338a-411f-80e4-d73fc9061b69")) {                    Plotly.newPlot(                        "73236a50-338a-411f-80e4-d73fc9061b69",                        [{"alignmentgroup":"True","boxpoints":"outliers","hovertemplate":"kind=%{x}\u003cbr\u003eминуты=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"кино","marker":{"color":"#636efa"},"name":"кино","notched":false,"offsetgroup":"кино","orientation":"v","showlegend":true,"x":["кино","кино
# ...

# %%
m= movies.dropna(subset=['runtimeMinutes'])
fig =px.scatter(m, x='runtimeMinutes', y='IMDb Rating', color='age', hover_name='title',
                 trendline='ols',title='кино - длительность и рейтинг IMDB',
                 labels={'runtimeMinutes' :'длительност, мин','IMDb Rating':'рейтинг IMDb', 'age':'аулитория'})
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="408eb73c-1252-41d6-a7bf-8e5c2e54c9ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("408eb73c-1252-41d6-a7bf-8e5c2e54c9ce")) {                    Plotly.newPlot(                        "408eb73c-1252-41d6-a7bf-8e5c2e54c9ce",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eаулитория=teen\u003cbr\u003eдлительност, мин=%{x}\u003cbr\u003eрейтинг IMDb=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["White Chicks","Zootopia","Finding Dory","Pete's Dragon","Kubo and the
# ...

# %% [markdown]
# Связь слабая, но положительная -- более длинные фильмы в среднем чуть выше по рейтингу (кэф корр около 0.24)
# то есть согласуется с тем, что короткие тайтлы - это часто детский и проходной контент.

# %% [markdown]
# ## 2.3 Рейтинг IMDb против пользовательской оценки Netflix
#
# Команда выше решила использовать рейтинг IMDb вместо user rating score (там было около 40% пропусков). Проверим, насколько эти две оценки вообще согласованы. Для сравнения приводим IMDb к шкале 0-100.

# %%
# сравниваем рейтинг IMDb с пользовательской оценкой из исходного датасета
cmp = pd.concat([movies.assign(kind='Кино'), tv.assign(kind='Сериалы')])
cmp = cmp.merge(clean[['title', 'user rating score']], on='title', how='left')
cmp['imdb_100'] = cmp['IMDb Rating'] * 10
cmp = cmp.dropna(subset=['user rating score', 'imdb_100'])

fig = px.scatter(cmp, x='imdb_100', y='user rating score', color='kind', hover_name='title',
                 title='Рейтинг IMDb против пользовательской оценки Netflix',
                 labels={'imdb_100': 'Рейтинг IMDb (шкала 0-100)', 'user rating score': 'рейтинг-скор'})
fig.update_layout(width=900, height=500)
fig.show()

print('Корреляция (всего тайтлов', len(cmp), '):', round(cmp['imdb_100'].corr(cmp['user rating score']), 3))
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="202cddc5-d695-4efb-9142-671fc0c2bce4" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("202cddc5-d695-4efb-9142-671fc0c2bce4")) {                    Plotly.newPlot(                        "202cddc5-d695-4efb-9142-671fc0c2bce4",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ekind=Кино\u003cbr\u003eРейтинг IMDb (шкала 0-100)=%{x}\u003cbr\u003eрейтинг-скор=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["White Chicks","Zootopia","Meet the Blacks","Finding Dory","Saus
# ...

# %% [markdown]
# Корреляция всего около 0.2 - то есть две оценки измеряют немного разное
# - User rating score - это оценка узкой аудитории Netflix
# - рейтинг IMDb собран на огромной и более широкой базе
#
# p.s.s-это доп аргумент чтобы опираться на imdb

# %% [markdown]
# ## 2.4 Динамика по годам
#
# посмотрим, как менялось  количество тайтлов и их средний рейтинг во времени
# берем сериалы - их в данных больше

# %%
rec = tv[tv['year'] >= 2010]
yr=rec.groupby('year').agg(n=('title', 'size'), rating=('IMDb Rating', 'mean')).reset_index()

fig = go.Figure()
fig.add_trace(go.Bar(x=yr['year'],y=yr['n'],name='кол-во тайтлов',
                     marker_color='skyblue', text=yr['n'],textposition='outside'))
fig.add_trace(go.Scatter(x=yr['year'],y=yr['rating'], name='Средний рейтинг', yaxis='y2',
                         mode='lines+markers',line=dict(color='crimson', width=3))
                         )
fig.update_layout(title='Сериалы Netflix по годам - кол-во и средний рейтинг',
                  xaxis_title='год', yaxis_title='кол-во тайтлов',
                  yaxis2=dict(title='средниый рейтинг IMDb', overlaying='y', side='right',range=[6,8]),
                  width=950, height=500, bargap=0.25)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="fc45e2f3-8f13-4f03-a052-717b6507b8fc" class="plotly-graph-div" style="height:500px; width:950px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fc45e2f3-8f13-4f03-a052-717b6507b8fc")) {                    Plotly.newPlot(                        "fc45e2f3-8f13-4f03-a052-717b6507b8fc",                        [{"marker":{"color":"skyblue"},"name":"кол-во тайтлов","text":{"dtype":"f8","bdata":"AAAAAAAAIEAAAAAAAAAYQAAAAAAAAC5AAAAAAAAAMEAAAAAAAAAxQAAAAAAAgEFAAAAAAADAVkAAAAAAAAA5QA=="},"textposition":"outside","x":{"dtype":"i2","bdata":"2gfbB9wH3QfeB98H4AfhBw=="},"y":{"dtype":"i1","bdata":"CAYPEBEjWxk="
# ...

# %% [markdown]
# Каталог почти целиком состоит из тайтлов 2010-х - это и есть период активного роста Netflix. Средний рейтинг при этом держится стабильно высоким, то есть рост каталога не привел к падению качества.

# %% [markdown]
# ## 2.5 Корреляция числовых признаков (seaborn)
#
# Соберем числовые признаки кино и сериалов вместе и посмотрим на их корреляцию. Это первый из графиков на seaborn.

# %%
# корреляционная матрица числовых признаков (seaborn heatmap)
num = pd.concat([
    movies[['year','runtimeMinutes','IMDb Rating','log_votes']],
    tv[['year','runtimeMinutes','IMDb Rating','log_votes']]]).dropna()
num = num.rename(columns={'runtimeMinutes':'runtime','IMDb Rating':'rating'})

plt.figure(figsize=(6, 5))
sns.heatmap(num.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f', square=True)
plt.title('Корреляция числовых признаков (кино + сериалы)')
# Out:
# Text(0.5, 1.0, 'Корреляция числовых признаков (кино + сериалы)')

# %% [markdown]
# Самая заметная связь - между рейтингом и числом оценок log_votes
# именно ее мы разберем дальше через функцию эластичности

# %% [markdown]
# # Часть 3. Дополнительное исследование - эластичность популярности по качеству
#
# **Гипотеза.** Популярность тайтла (число оценок на IMDb, numVotes как прокся охвата и спроса) растет быстрее, чем его качество (рейтинг IMDb). То есть связь не просто положительная, а **сверхэластичная**: рост рейтинга на 1% дает рост популярности больше чем на 1%.
#
# Почему вообще тут эластичность
# Эластичность y по x - это процентное изменение Y на 1% изменения X
#
# если оценивать регрессию в логарифмах
# `ln(numVotes) = a + E * ln(IMDb Rating)`,
#
# то коэффициент `E` при `ln(IMDb Rating)` и есть эластичность
# логарифмирование здесь уместна - число оценок имеет очень длинный правый хвост, а в логарифмах связь становится линейной
#
# Если `E > 1` - спрос сверхэластичен по качеству -небольшой рост рейтинга дает непропорционально большой рост аудитории

# %%
# готовим данные для лог-лог регрессии 
reg = pd.concat([movies.assign(kind='movie'), tv.assign(kind='tv')])
reg = reg[(reg['numVotes'] > 0) & (reg['IMDb Rating'] > 0)].dropna(subset=['numVotes','IMDb Rating'])

reg['ln_votes'] = np.log(reg['numVotes'])
reg['ln_rating'] = np.log(reg['IMDb Rating'])

# оцениваем эластичность отдельно для кино и сериалов
def elasticity(df):
    m=smf.ols('ln_votes ~ ln_rating',data=df).fit(cov_type='HC3')
    e = m.params['ln_rating']
    lo,hi = m.conf_int().loc['ln_rating']
    
    return m, e, lo, hi
el = {}
for name, key in [('кино','movie'), ('cериалы','tv')]:
    m,e,lo,hi=elasticity(reg[reg['kind']==key])
    el[key] = e
    print(f'{name}: эластичность={e.round(2)}  (95% ДИ {round(lo,2)} --{round(hi,2)}),  R2 ={m.rsquared.round(2)},  p = {m.pvalues["ln_rating"].round(10)},  n {int(m.nobs)}')
# Out:
# кино: эластичность=6.39  (95% ДИ 4.43 --8.34),  R2 =0.31,  p = 2e-10,  n 121
# cериалы: эластичность=7.79  (95% ДИ 5.42 --10.16),  R2 =0.28,  p = 1e-10,  n 235

# %% [markdown]
# Эластичность получилась около **6.4 для кино** и **8.0 для сериалов**, обе высоко значимы (p намного меньше 0.001) и сильно больше 1. То есть гипотеза о сверхэластичности подтверждается: качество влияет на охват не линейно, а с большим мультипликатором.

# %%
# главный график: лог-лог связь с регрессионной линией отдельно для кино и сериалов
fig = px.scatter(reg, x='IMDb Rating', y='numVotes', color='kind', hover_name='title',
                 log_x=True, log_y=True, trendline='ols',
                 trendline_options=dict(log_x=True, log_y=True),
                 title='Эластичность популярности по качеству',
                 labels={'numVotes':'число оценок на IMDb','IMDb Rating': 'рейтинг IMDb'})

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="e628b184-587c-481b-986a-28ffe588197e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e628b184-587c-481b-986a-28ffe588197e")) {                    Plotly.newPlot(                        "e628b184-587c-481b-986a-28ffe588197e",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ekind=movie\u003cbr\u003eрейтинг IMDb=%{x}\u003cbr\u003eчисло оценок на IMDb=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["White Chicks","Lucky Number Slevin","The Hunter","Hyena Road","Sex, L
# ...

# %%
# та же связь через seaborn - отдельно кино и сериалы
reg['log10_votes'] = np.log10(reg['numVotes'])

g = sns.lmplot(data=reg, x='IMDb Rating', y='log10_votes', col='kind',
               height=4, aspect=1.1, scatter_kws={'alpha': 0.4, 's': 25}, line_kws={'color': 'crimson'})
g.set_axis_labels('Рейтинг IMDb', 'log10(число оценок)')
g.set_titles('{col_name}')
g.fig.suptitle('Связь популярности и качества (кино и сериалы)', y=1.04)
plt.show()

# %% [markdown]
# ## 3.1 Проверка устойчивости результата
#
# Сверхэластичность могла бы быть случайной - проверим, что она не разваливается при добавлении контролей и при удалении выбросов.

# %%
# для простоыт задам функцию
reg['ln_runtime'] = np.log(reg['runtimeMinutes'])

def q(df,f):
    m = smf.ols(f,data=df).fit(cov_type='HC3')
    el,pval,r2=round(m.params['ln_rating'],2), round(m.pvalues['ln_rating'],4), round(m.rsquared, 2)
    return f"эластич={el}, p-value={pval}, r2={r2}"

# %%
#базовая модель
print(q(reg[reg['kind']=='movie'],'ln_votes~ln_rating'))
print(q(reg[reg['kind']=='tv'],'ln_votes~ln_rating'))
# Out:
# эластич=6.39, p-value=0.0, r2=0.31
# эластич=7.79, p-value=0.0, r2=0.28

# %%
# с корректировко й на длит
sub=reg.dropna(subset=['ln_runtime'])
print(q(sub[sub['kind']=='movie'],'ln_votes~ln_rating +ln_runtime'))
print(q(sub[sub['kind']=='tv'],'ln_votes~ln_rating +ln_runtime'))
# Out:
# эластич=5.86, p-value=0.0, r2=0.34
# эластич=7.13, p-value=0.0, r2=0.38

# %%
#без выбросов
dfm,dftv=reg[reg['kind']=='movie'], reg[reg['kind']=='tv']

dfm=dfm[dfm['numVotes'].between(dfm['numVotes'].quantile(0.05), dfm['numVotes'].quantile(0.95))]
dftv=dftv[dftv['numVotes'].between(dftv['numVotes'].quantile(0.05), dftv['numVotes'].quantile(0.95))]

print(q(dfm,'ln_votes~ln_rating'))
print(q(dftv,'ln_votes~ln_rating'))
# Out:
# эластич=5.81, p-value=0.0, r2=0.31
# эластич=7.19, p-value=0.0, r2=0.33

# %% [markdown]
# Эластичность остается в районе 6 для кино и 7-7,5 для сериалов во всех вариантах то есть результат устойчив
#
# контроль на длительность ее почти не меняет, значит дело именно в качестве, а не в том что хорошие тайтлы заодно еще и  длиннее

# %% [markdown]
# ## 3.2 Что это значит для бизнеса
#
# Переведем эластичность в понятные цифры: во сколько раз меняется аудитория (число оценок) при росте рейтинга относительно базового уровня 7.0.

# %%
# практический смысл: множитель аудитории относительно рейтинга 7.0
base = 7.0
ratings = np.arange(6.0, 9.01, 0.1)

fig = go.Figure()
fig.add_trace(go.Scatter(x=ratings, y=(ratings / base) ** el['movie'],
                         name=f'Кино (E={el["movie"]:.1f})', mode='lines', line=dict(width=3)))
fig.add_trace(go.Scatter(x=ratings, y=(ratings / base) ** el['tv'],
                         name=f'Сериалы (E={el["tv"]:.1f})', mode='lines', line=dict(width=3)))
fig.add_hline(y=1, line_dash='dot', line_color='gray')
fig.update_layout(title='Во сколько раз меняется аудитория относительно рейтинга 7.0',
                  xaxis_title='Рейтинг IMDb', yaxis_title='Множитель числа оценок',
                  width=900, height=500)
fig.show()

for key, name in [('movie', 'Кино'), ('tv', 'Сериалы')]:
    print(f'{name}: рост рейтинга 7.0 -> 7.5 дает примерно x{(7.5/7.0)**el[key]:.2f} к числу оценок')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="15efe6c1-eb09-4af3-898d-2807f1e8b7b4" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("15efe6c1-eb09-4af3-898d-2807f1e8b7b4")) {                    Plotly.newPlot(                        "15efe6c1-eb09-4af3-898d-2807f1e8b7b4",                        [{"line":{"width":3},"mode":"lines","name":"Кино (E=6.4)","x":{"dtype":"f8","bdata":"AAAAAAAAGEBmZmZmZmYYQMzMzMzMzBhAMjMzMzMzGUCYmZmZmZkZQP7\u002f\u002f\u002f\u002f\u002f\u002fxlAZGZmZmZmGkDKzMzMzMwaQDAzMzMzMxtAlpmZmZmZG0D8\u002f\u002f\u002f\u002f\u002f\u002f8bQGJmZmZmZhxAyMzMzMzMHEAuMzMzMzMdQJ
# ...

# %% [markdown]
# **Вывод.** Спрос на контент сверхэластичен по качеству. Поднять рейтинг тайтла с 7.0 до 7.5 (всего около +7%) - значит увеличить аудиторию примерно в 1.5-1.7 раза. Это классический "superstar"-эффект индустрии контента: небольшое преимущество в качестве дает непропорционально большой охват.
#
# Практический смысл для заказчика: вложения в качество (сценарий, продакшн, отбор проектов) окупаются мультипликативно через охват, а не линейно. Лучше сделать меньше, но заметно более качественных тайтлов, чем много средних.

# %% [markdown]
# # Часть 4. Итоговые выводы
#
# 1. **Жанры.** Выше всего по рейтингу - Crime, Mystery, Drama, Thriller; массовые жанры (Animation, Family, Comedy) в среднем оцениваются ниже. Высокий рейтинг и большой охват - это не одно и то же.
# 2. **Длительность.** Более длинные фильмы в среднем чуть выше по рейтингу, но связь слабая.
# 3. **Две оценки качества.** Рейтинг IMDb и user rating score Netflix согласованы слабо (корреляция около 0.2), поэтому опора на IMDb оправдана - он полнее и устойчивее.
# 4. **Динамика.** Каталог - это в основном тайтлы 2010-х, рост каталога не уронил средний рейтинг.
# 5. **Главное исследование - эластичность.** Популярность сверхэластична по качеству: эластичность около 6 для кино и 8 для сериалов, результат устойчив к контролям и выбросам. Рост рейтинга на 1% дает 6-8% роста аудитории. Для бизнеса это означает, что ставка на качество окупается мультипликативно.
#
# **Ответ на бизнес-вопрос.** Главный рычаг охвата при отборе контента - это качество: повышение рейтинга дает непропорционально большой прирост аудитории (эластичность 6-8). Поэтому при ограниченном бюджете выгоднее вкладываться в меньшее число более качественных тайтлов и отбирать проекты с высоким ожидаемым рейтингом, а не наращивать количество среднего контента.

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за курсовой проект в целом — то есть первая из двух оценок — выставляется по 10 балльной шкале, исходя из 5 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже

# %% [markdown]
# ### Критерий 1. Информативность техническая – необходимо выявить нетривиальные зависимости и тенденции в данных (до 2 баллов)
#
# Данный критерий оценивает, насколько вы продвинулись технически с точки зрения выявления каких-то паттернов, тенденций и зависимостей в данных. Чем более сложные инструменты вы примените в ходе выполнения проекта и чем более сложные и нетривиальные зависимости получите, тем выше будет оценка у вашей команды по данному критерию!

# %% [markdown]
# ### Критерий 2. Информативность аналитическая – необходимо интерпретировать данные и делать выводы полезные для бизнеса  (до 2 баллов)
#
# Данный критерий оценивает прикладной смысл проделанных вами действий, интерпретацию технических инструментов, умение подсветить полезность и значимость полученных выводов с точки зрения бизнеса, умение переложить полученные результаты на исходные бизнес-цели и "продать" то, что вы сделали.

# %% [markdown]
# ### Критерий 3. Визуализация – оценивается техническое исполнение графиков (до 2 баллов)
#
# Данный критерий оценивает сложность и техничность ваших визуализаций. Визуализации должны быть наглядными, красивыми, понятными, легко-интерпертируемыми, нетривиальными с точки зрения технического исполнения и выводов, которые они несут в себе.
#
#
# *Максимальный балл по данному критерию (**2 балла**) нельзя получить, если в работе используются лишь базовые библиотеки визуализаций: Matplotlib и Seaborn*

# %% [markdown]
# ### Критерий 4. Предобработка датасета – очистка/замена данных (до 1 балла)
#
# Данный критерий оценивает полноту всех проделанных действий с точки зрения подготовки данных и первичной предобработки датасета.

# %% [markdown]
# ### Критерий 5. Обогащение данными – добавление новых признаков/датасетов (до 3 баллов)
#
# Данный критерий оценивает полноту использования средств feature engineering на основе имеющихся данных, а также средств обогащения данных путем дополнения имеющегося датасета значимой информацией из связанных сторонних датасетов, различных внешних ресурсов и других источников. Обратите внимание, что связанная информация извне не должна замещать или подменять собой исходную задачу и исходные данные в представленном датасете, а должна лишь дополнять и обогощать его. Корректность и глубина проработки взаимодействия со внешними ресурсами и оценивается в рамках данного критерия!
#
# *Максимальный балл по данному критерию (**3 балла**) можно получить только при условии корректной и значимой работы с как минимум двумя источниками внешних данных (двумя внешними датасетами), а также при условии наличия как минимум двух примеров валидного и осмысленного применения средств feature engineering*
#
# *По данному критерию можно получить **2 балла** только при условии корректной и значимой работы с как минимум одним источником внешних данных (внешним датасетом), а также при условии наличия как минимум одного примера валидного и осмысленного применения средств feature engineering*
